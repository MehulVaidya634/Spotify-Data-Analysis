# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tracks_features.csv')

# %%
df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (1204025, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204025 entries, 0 to 1204024
# Data columns (total 24 columns):
# id                  1204025 non-null object
# name                1204025 non-null object
# album               1204025 non-null object
# album_id            1204025 non-null object
# artists             1204025 non-null object
# artist_ids          1204025 non-null object
# track_number        1204025 non-null int64
# disc_number         1204025 non-null int64
# explicit            1204025 non-null bool
# danceability        1204025 non-null float64
# energy              1204025 non-null float64
# key                 1204025 non-null int64
# loudness            1204025 non-null float64
# mode                1204025 non-null int64
# speechiness         1204025 non-null float64
# acousticness        1204025 non-null float64
# instrumentalness    1204025 non-null float64
# liveness            1204025 non-null float64
# valence             1204025 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# name                0
# album               0
# album_id            0
# artists             0
# artist_ids          0
# track_number        0
# disc_number         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# year                0
# release_date        0
# dtype: int64

# %%
df.describe()
# Out:
#        track_number   disc_number  danceability        energy           key  \
# count  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06
# mean   7.656352e+00  1.055906e+00  4.930565e-01  5.095363e-01  5.194151e+00
# std    5.994977e+00  2.953752e-01  1.896694e-01  2.946839e-01  3.536731e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.000000e+00  1.000000e+00  3.560000e-01  2.520000e-01  2.000000e+00
# 50%    7.000000e+00  1.000000e+00  5.010000e-01  5.240000e-01  5.000000e+00
# 75%    1.000000e+01  1.000000e+00  6.330000e-01  7.660000e-01  8.000000e+00
# max    5.000000e+01  1.300000e+01  1.000000e+00  1.000000e+00  1.100000e+01
#
#            loudness          mode   speechiness  acousticness  \
# count  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06
# mean  -1.180870e+01  6.714595e-01  8.438219e-02  4.467511e-01
# std    6.982132e+00  4.696827e-01  1.159914e-01  3.852014e-01
# ...

# %%
df.corr()
# Out:
#                   track_number  disc_number  explicit  danceability    energy  \
# track_number          1.000000    -0.005175 -0.017275     -0.041665 -0.124871
# disc_number          -0.005175     1.000000 -0.034758     -0.073758 -0.078767
# explicit             -0.017275    -0.034758  1.000000      0.194316  0.162870
# danceability         -0.041665    -0.073758  0.194316      1.000000  0.283016
# energy               -0.124871    -0.078767  0.162870      0.283016  1.000000
# key                  -0.002315    -0.005026  0.007292      0.018633  0.034452
# loudness             -0.144221    -0.097418  0.163154      0.378194  0.817934
# mode                  0.012315     0.010846 -0.053346     -0.021528 -0.035788
# speechiness           0.045695    -0.011852  0.336887      0.209859  0.130813
# acousticness          0.127427     0.089302 -0.182155     -0.285750 -0.796242
# instrumentalness      0.037038     0.027788 -0.161286     -0.285331 -0.252131
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), linewidths = 0.5, annot = True)

# %% [markdown]
# # Questions.
#
# 1. Which year, month and day had the most songs released?
#
# 2. what were the top 10 dancable songs?
#
# 3. whcih Album had the most releases?
#
# 4. what is average duration of songs in minutes?
#
# 5. what were the top 10 songs with the most loudness and tempo?

# %%
year = df['year'].value_counts()

# %%
#1.which year, month and day had the most no fo somgs released?
year[:20].plot(kind = 'bar' , figsize = (10,10))

# %%
month = df['release_date'].str.split('-').str[1]

# %%
day = df['release_date'].str.split('-').str[2]

# %%
month.value_counts()
# Out:
# 01    180260
# 10    105456
# 09     92267
# 11     90896
# 06     84943
# 05     84050
# 04     81970
# 03     81872
# 08     78672
# 02     72357
# 07     71363
# 12     49775
# Name: release_date, dtype: int64

# %%
month.value_counts().plot(kind = 'barh', figsize = (9,9))

# %%
day_count = day.value_counts()

# %%
day_count[:10].plot(kind = 'bar', figsize = (8,8))

# %%
df['explicit'].value_counts().plot(kind = 'pie', figsize = (7,8), autopct='%.0f%%')

# %%
#is there a relation between liveness and loudness/
fig = plt.figure(figsize = (10,6))
sns.relplot(x="liveness", y="loudness", kind="line", data=df)

# %%
album  = df['album'].value_counts()

# %%
#Album with the most no fo songs.
album[:15].plot(kind = 'bar', figsize = (9,7))

# %%
#How has tempo changed over the years?
fig = plt.figure(figsize = (10,6))
g = sns.relplot(x="year", y="tempo", kind="line", data=df)
g.set(xlim=(1990, 2020))
g.set(ylim=(110, 122))

# %%
# Top 10 most dancable songs.
df[['name', 'artists', 'album', 'danceability', 'year']].sort_values(by = 'danceability', ascending = False).head(10)
# Out:
#                                          name               artists  \
# 456635                              Unendlich    ['Wolfgang Voigt']
# 726027                    Na-try Mo Na Ba Ako         ['Andrew E.']
# 1192428  Roll Like Dis / Cha-cha Slide Part 2             ['Mr. C']
# 765603                    Techno Is Not Fault  ['Andrea HEinstein']
# 777038      Le casse-tête (Cannelle, Pruneau)     ['Passe-Partout']
# 726033              Aussie, Aussie (O, Sige!)         ['Andrew E.']
# 145357                          Esther's Vice       ['Bexar Bexar']
# 304523                               New Life     ['Matias Aguayo']
# 439816                                Go Nuts           ['Edidion']
# 744512                        Believe In Love  ['The Wooden Birds']
#
#                                                   album  danceability  year
# 456635                                    Versammlung 1         1.000  2015
# ...

# %%
# What is the average, median and mode duration in minutes of songs.
print('The Average duration in mins: ',df['duration_ms'].mean()/60000)
print('The Average duration in mins: ',df['duration_ms'].median()/60000)
print('The Average duration in mins: ',df['duration_ms'].mode()/60000)
# Out:
# The Average duration in mins:  4.147331016036489
# The Average duration in mins:  3.7389833333333335
# The Average duration in mins:  0    4.0
# dtype: float64

# %%
# Songs with the most tempo ?
df[['name', 'album', 'artists', 'tempo']].sort_values('tempo', ascending=False).head(10)
# Out:
#                             name                                  album  \
# 934980               Trap Addict                 United States of Trapp
# 1153874      Nxnc - Original Mix                          The Beginning
# 836368   Follow You Down - Mixed  Global Underground: Select #2 (Mixed)
# 53734                      Pecan       Rave on Snow Compilation, Vol.15
# 456633                Tubass 1.2                          Versammlung 1
# 902303             Driving Wheel                       Back In The Game
# 781866                   Reunion                  Ultimate Love, Vol. 1
# 863056         The Holy Mountain                                  Choke
# 795098        Don't Cross Myrtle                     Don't Cross Myrtle
# 781862         Surrender to Love                  Ultimate Love, Vol. 1
#
#                     artists    tempo
# 934980     ['UNDERCODEINE']  248.934
# 1153874           ['ToBee']  247.996
# 836368         ['Just Her']  246.883
# ...

# %%
# Songs with most loudess.
df[['name', 'album', 'artists','year' , 'loudness']].sort_values(by = 'loudness', ascending=False).head(10)
# Out:
#                          name album           artists  year  loudness
# 1018788                Bucket  Dash  ['Sissy Spacek']  2010     7.234
# 1018799        Mondo Employee  Dash  ['Sissy Spacek']  2010     7.115
# 1018801             Norge Est  Dash  ['Sissy Spacek']  2010     6.980
# 1018792        Devil May Care  Dash  ['Sissy Spacek']  2010     6.863
# 1018787         (The) Repulse  Dash  ['Sissy Spacek']  2010     6.798
# 1018816           Fantasaster  Dash  ['Sissy Spacek']  2010     6.774
# 1018791          Killer Slook  Dash  ['Sissy Spacek']  2010     6.674
# 1018802  Your Boat Is Missing  Dash  ['Sissy Spacek']  2010     6.671
# 1018800                  Trim  Dash  ['Sissy Spacek']  2010     6.627
# 1018820                Smilax  Dash  ['Sissy Spacek']  2010     6.627

# %% [markdown]
# # Insights.
#
# 1. Increase in songs been released every year.
#
# 2. 175000+ songs have been released  in the 1st month.
#
# 3. Top 10 songs with most loudness were made by the same album named 'Dash'.
#
# 4. Most dancable songs were released after year 2000.
#
# 5. Greatest hits is the album with the most no of songs.

# %%
fig = plt.figure(figsize = (10,6))
d = sns.relplot(x="danceability", y="valence", kind="line", data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig = plt.figure(figsize = (10,6))
e = sns.relplot(x="energy", y="loudness", kind="line", data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
